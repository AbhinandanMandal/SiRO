# %%
import pandas as pd
OOWLDoubleEmbCSV = pd.read_csv('/home/saswata/Downloads/SIOR-master/DoubleEmbdTrainedResults/ObjectPI/1_OOWLbenchmark.csv')
MNet40DoubleEmbCSV = pd.read_csv('/home/saswata/Downloads/SIOR-master/DoubleEmbdTrainedResults/ModelNet40/1_MNet40benchmark.csv')
FG3DDoubleEmbCSV = pd.read_csv('/home/saswata/Downloads/SIOR-master/DoubleEmbdTrainedResults/FG3D/1_FG3Dbenchmark.csv')

OOWLDoubleEmbCSV.head()
# Out:
#    epoch  train_loss   test_acc  useful_exemplar_%  maxdisintra  disintra  \
# 0      0   47.522332  68.622449         100.000000     1.254032  0.999641
# 1      1    9.937243  70.790816         100.000000     0.917686  0.686374
# 2      2    1.348346  69.515306         100.000000     0.829257  0.608970
# 3      3    0.519445  68.494898         100.000000     0.738389  0.535649
# 4      4    0.394854  69.515306          99.554974     0.651821  0.465384
#
#    interCN_catg  interCN_min     ratio
# 0      3.546753     3.347452  2.669351
# 1      3.044224     2.581006  2.812515
# 2      3.207851     2.556215  3.082537
# 3      3.285373     2.506274  3.394246
# 4      3.299743     2.435191  3.735981

# %% [markdown]
# *Train Loss vs Epoch*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

# Plot each dataset
plt.plot(OOWLDoubleEmbCSV["epoch"], OOWLDoubleEmbCSV["train_loss"], 
         label="ObjectPI", linewidth=1.5)

plt.plot(MNet40DoubleEmbCSV["epoch"], MNet40DoubleEmbCSV["train_loss"], 
         label="ModelNet40", linewidth=1.5)

plt.plot(FG3DDoubleEmbCSV["epoch"], FG3DDoubleEmbCSV["train_loss"], 
         label="FG3D", linewidth=1.5)

# Labels and title
plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.title("Double Embedding Model")

# Legend (clean style)
plt.legend(frameon=True)

# Subtle grid
plt.grid(True, linestyle="--")

# Remove top/right borders (CVPR style)
# sns.despine()

plt.tight_layout()
plt.savefig("TrainLoss_Epoch_DEM.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# *Test Accuracy vs Epoch*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

# Plot each dataset
plt.plot(OOWLDoubleEmbCSV["epoch"], OOWLDoubleEmbCSV["test_acc"], 
         label="ObjectPI", linewidth=1.5)

plt.plot(MNet40DoubleEmbCSV["epoch"], MNet40DoubleEmbCSV["test_acc"], 
         label="ModelNet40", linewidth=1.5)

plt.plot(FG3DDoubleEmbCSV["epoch"], FG3DDoubleEmbCSV["test_acc"], 
         label="FG3D", linewidth=1.5)

# Labels and title
plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.title("Double Embedding Model")

# Legend (clean style)
plt.legend(frameon=True)

# Subtle grid
plt.grid(True, linestyle="--")

# Remove top/right borders (CVPR style)
# sns.despine()

plt.tight_layout()
plt.savefig("TestAccuracy_Epoch_DEM.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# *Disintra vs Epoch*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

# Plot each dataset
plt.plot(OOWLDoubleEmbCSV["epoch"], OOWLDoubleEmbCSV["disintra"], 
         label="ObjectPI", linewidth=1.5)

plt.plot(MNet40DoubleEmbCSV["epoch"], MNet40DoubleEmbCSV["disintra"], 
         label="ModelNet40", linewidth=1.5)

plt.plot(FG3DDoubleEmbCSV["epoch"], FG3DDoubleEmbCSV["disintra"], 
         label="FG3D", linewidth=1.5)

# Labels and title
plt.xlabel("Epoch")
plt.ylabel("Disintra")
plt.title("Double Embedding Model")

# Legend (clean style)
plt.legend(frameon=True)

# Subtle grid
plt.grid(True, linestyle="--")

# Remove top/right borders (CVPR style)
# sns.despine()

plt.tight_layout()
plt.savefig("Disintra_Epoch_DEM.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# *InterCN_catg vs Epoch*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

# Plot each dataset
plt.plot(OOWLDoubleEmbCSV["epoch"], OOWLDoubleEmbCSV["interCN_catg"], 
         label="ObjectPI", linewidth=1.5)

plt.plot(MNet40DoubleEmbCSV["epoch"], MNet40DoubleEmbCSV["interCN_catg"], 
         label="ModelNet40", linewidth=1.5)

plt.plot(FG3DDoubleEmbCSV["epoch"], FG3DDoubleEmbCSV["interCN_catg"], 
         label="FG3D", linewidth=1.5)

# Labels and title
plt.xlabel("Epoch")
plt.ylabel("InterCN_catg")
plt.title("Double Embedding Model")

# Legend (clean style)
plt.legend(frameon=True)

# Subtle grid
plt.grid(True, linestyle="--")

# Remove top/right borders (CVPR style)
# sns.despine()

plt.tight_layout()
plt.savefig("InterCN_catg_Epoch_DEM.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# *InterCN_min vs Epoch*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

# Plot each dataset
plt.plot(OOWLDoubleEmbCSV["epoch"], OOWLDoubleEmbCSV["interCN_min"], 
         label="ObjectPI", linewidth=1.5)

plt.plot(MNet40DoubleEmbCSV["epoch"], MNet40DoubleEmbCSV["interCN_min"], 
         label="ModelNet40", linewidth=1.5)

plt.plot(FG3DDoubleEmbCSV["epoch"], FG3DDoubleEmbCSV["interCN_min"], 
         label="FG3D", linewidth=1.5)

# Labels and title
plt.xlabel("Epoch")
plt.ylabel("InterCN_min")
plt.title("Double Embedding Model")

# Legend (clean style)
plt.legend(frameon=True)

# Subtle grid
plt.grid(True, linestyle="--")

# Remove top/right borders (CVPR style)
# sns.despine()

plt.tight_layout()
plt.savefig("InterCN_min_Epoch_DEM.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# **Visualizing Trends For 50 More Epochs**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

OOWL = pd.read_csv('/home/saswata/Downloads/SIOR-master/DoubleEmbdTrainedResults/ObjectPI/1_OOWLbenchmark.csv')
MNet = pd.read_csv('/home/saswata/Downloads/SIOR-master/DoubleEmbdTrainedResults/ModelNet40/1_MNet40benchmark.csv')
FG3D = pd.read_csv('/home/saswata/Downloads/SIOR-master/DoubleEmbdTrainedResults/FG3D/1_FG3Dbenchmark.csv')



def extend_epochs(df, extra_epochs=50):
    last_epoch = df["epoch"].iloc[-1]
    new_epochs = np.arange(last_epoch + 1, last_epoch + 1 + extra_epochs)
    
    new_df = pd.DataFrame({"epoch": new_epochs})

    for col in df.columns:
        if col == "epoch":
            continue
        
        series = df[col]
        ema = series.ewm(span=5).mean()
        
        trend = ema.iloc[-1] - ema.iloc[-2]
        last_val = ema.iloc[-1]
        values = []

        for _ in range(extra_epochs):
            trend *= 0.9
            last_val = last_val + trend
            values.append(last_val)

        new_df[col] = values

    return pd.concat([df, new_df], ignore_index=True)


OOWL_ext = extend_epochs(OOWL)
MNet_ext = extend_epochs(MNet)
FG3D_ext = extend_epochs(FG3D)

# %% [markdown]
# *Train Loss vs Epoch*

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

plt.plot(OOWL_ext["epoch"], OOWL_ext["train_loss"], 
         label="ObjectPI", linewidth=1.5, linestyle="-")

plt.plot(MNet_ext["epoch"], MNet_ext["train_loss"], 
         label="ModelNet40", linewidth=1.5, linestyle="-")

plt.plot(FG3D_ext["epoch"], FG3D_ext["train_loss"], 
         label="FG3D", linewidth=1.5, linestyle="-")

plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.title("Double Embedding Model +50 Epoch Extrapolation")

plt.legend(frameon=True)
plt.grid(True, linestyle="--")

sns.despine()
plt.tight_layout()

plt.savefig("TrainLoss_Epoch_DEM_50.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def plot_with_split(df, label, linestyle):
    orig_len = len(df) - 50
    
    plt.plot(df["epoch"][:orig_len], df["train_loss"][:orig_len],
             linestyle=linestyle, linewidth=1.5, label=label)
    
    plt.plot(df["epoch"][orig_len:], df["train_loss"][orig_len:],
             linestyle=linestyle, linewidth=1.5)
    
plt.figure(figsize=(6,4))

plot_with_split(OOWL_ext, "ObjectPI", "-")
plot_with_split(MNet_ext, "ModelNet40", "-")
plot_with_split(FG3D_ext, "FG3D", "-")

plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.title('Real vs Extrapolated')

plt.legend(frameon=True)
plt.show()

# %% [markdown]
# *Test Accuracy vs Epoch*

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

plt.plot(OOWL_ext["epoch"], OOWL_ext["test_acc"], 
         label="ObjectPI", linewidth=1.5, linestyle="-")

plt.plot(MNet_ext["epoch"], MNet_ext["test_acc"], 
         label="ModelNet40", linewidth=1.5, linestyle="-")

plt.plot(FG3D_ext["epoch"], FG3D_ext["test_acc"], 
         label="FG3D", linewidth=1.5, linestyle="-")

plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.title("Dual Embedding Model +50 Epoch Extrapolation")

plt.legend(frameon=True)
plt.grid(True, linestyle="--")

sns.despine()
plt.tight_layout()

plt.savefig("TestAccuracy_Epoch_DEM_50.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def plot_with_split(df, label, linestyle):
    orig_len = len(df) - 50
    
    plt.plot(df["epoch"][:orig_len], df["test_acc"][:orig_len],
             linestyle=linestyle, linewidth=1.5, label=label)
    
    plt.plot(df["epoch"][orig_len:], df["test_acc"][orig_len:],
             linestyle=linestyle, linewidth=1.5)
    
plt.figure(figsize=(6,4))

plot_with_split(OOWL_ext, "ObjectPI", "-")
plot_with_split(MNet_ext, "ModelNet40", "-")
plot_with_split(FG3D_ext, "FG3D", "-")

plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.title('Real vs Extrapolated')

plt.legend(frameon=True)
plt.show()

# %% [markdown]
# *Disintra vs Epoch*

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

plt.plot(OOWL_ext["epoch"], OOWL_ext["disintra"], 
         label="ObjectPI", linewidth=1.5, linestyle="-")

plt.plot(MNet_ext["epoch"], MNet_ext["disintra"], 
         label="ModelNet40", linewidth=1.5, linestyle="-")

plt.plot(FG3D_ext["epoch"], FG3D_ext["disintra"], 
         label="FG3D", linewidth=1.5, linestyle="-")

plt.xlabel("Epoch")
plt.ylabel("Disintra")
plt.title("Dual Embedding Model +50 Epoch Extrapolation")

plt.legend(frameon=True)
plt.grid(True, linestyle="--")

sns.despine()
plt.tight_layout()

plt.savefig("Disintra_Epoch_DEM_50.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def plot_with_split(df, label, linestyle):
    orig_len = len(df) - 50
    
    plt.plot(df["epoch"][:orig_len], df["disintra"][:orig_len],
             linestyle=linestyle, linewidth=1.5, label=label)
    
    plt.plot(df["epoch"][orig_len:], df["disintra"][orig_len:],
             linestyle=linestyle, linewidth=1.5)
    
plt.figure(figsize=(6,4))

plot_with_split(OOWL_ext, "ObjectPI", "-")
plot_with_split(MNet_ext, "ModelNet40", "-")
plot_with_split(FG3D_ext, "FG3D", "-")

plt.xlabel("Epoch")
plt.ylabel("Disintra")
plt.title('Real vs Extrapolated')

plt.legend(frameon=True)
plt.show()

# %% [markdown]
# *InterCN_catg vs Epoch*

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

plt.plot(OOWL_ext["epoch"], OOWL_ext["interCN_catg"], 
         label="ObjectPI", linewidth=1.5, linestyle="-")

plt.plot(MNet_ext["epoch"], MNet_ext["interCN_catg"], 
         label="ModelNet40", linewidth=1.5, linestyle="-")

plt.plot(FG3D_ext["epoch"], FG3D_ext["interCN_catg"], 
         label="FG3D", linewidth=1.5, linestyle="-")

plt.xlabel("Epoch")
plt.ylabel("InterCN_catg")
plt.title("Dual Embedding Model +50 Epoch Extrapolation")

plt.legend(frameon=True)
plt.grid(True, linestyle="--")

sns.despine()
plt.tight_layout()

plt.savefig("InterCN_catg_Epoch_DEM_50.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def plot_with_split(df, label, linestyle):
    orig_len = len(df) - 50
    
    plt.plot(df["epoch"][:orig_len], df["interCN_catg"][:orig_len],
             linestyle=linestyle, linewidth=1.5, label=label)
    
    plt.plot(df["epoch"][orig_len:], df["interCN_catg"][orig_len:],
             linestyle=linestyle, linewidth=1.5)
    
plt.figure(figsize=(6,4))

plot_with_split(OOWL_ext, "ObjectPI", "-")
plot_with_split(MNet_ext, "ModelNet40", "-")
plot_with_split(FG3D_ext, "FG3D", "-")

plt.xlabel("Epoch")
plt.ylabel("InterCN_catg")
plt.title('Real vs Extrapolated')

plt.legend(frameon=True)
plt.show()

# %% [markdown]
# *InterCN_min vs Epoch*

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))

plt.plot(OOWL_ext["epoch"], OOWL_ext["interCN_min"], 
         label="ObjectPI", linewidth=1.5, linestyle="-")

plt.plot(MNet_ext["epoch"], MNet_ext["interCN_min"], 
         label="ModelNet40", linewidth=1.5, linestyle="-")

plt.plot(FG3D_ext["epoch"], FG3D_ext["interCN_min"], 
         label="FG3D", linewidth=1.5, linestyle="-")

plt.xlabel("Epoch")
plt.ylabel("InterCN_min")
plt.title("Dual Embedding Model +50 Epoch Extrapolation")

plt.legend(frameon=True)
plt.grid(True, linestyle="--")

sns.despine()
plt.tight_layout()

plt.savefig("InterCN_min_Epoch_DEM_50.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
def plot_with_split(df, label, linestyle):
    orig_len = len(df) - 50
    
    plt.plot(df["epoch"][:orig_len], df["interCN_min"][:orig_len],
             linestyle=linestyle, linewidth=1.5, label=label)
    
    plt.plot(df["epoch"][orig_len:], df["interCN_min"][orig_len:],
             linestyle=linestyle, linewidth=1.5)
    
plt.figure(figsize=(6,4))

plot_with_split(OOWL_ext, "ObjectPI", "-")
plot_with_split(MNet_ext, "ModelNet40", "-")
plot_with_split(FG3D_ext, "FG3D", "-")

plt.xlabel("Epoch")
plt.ylabel("InterCN_min")
plt.title('Real vs Extrapolated')

plt.legend(frameon=True)
plt.show()
